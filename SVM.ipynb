# %% [markdown]
# <a href="https://colab.research.google.com/github/Him-Shrivas/machine_learning_SVM/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Predict if cancer is beningn or malignan using Support Vector Machine implementation in python

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_breast_cancer
cancer=load_breast_cancer()
df=pd.DataFrame(np.c_[cancer['data'],cancer['target']],columns=np.append(cancer['feature_names'],['target']))
df.head(2)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
#
#    worst symmetry  worst fractal dimension  target
# ...

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
df.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.323782        0.997855   0.987357
# mean texture                0.323782      1.000000        0.329533   0.321086
# mean perimeter              0.997855      0.329533        1.000000   0.986507
# mean area                   0.987357      0.321086        0.986507   1.000000
# mean smoothness             0.170581     -0.023389        0.207278   0.177028
# mean compactness            0.506124      0.236702        0.556936   0.498502
# mean concavity              0.676764      0.302418        0.716136   0.685983
# mean concave points         0.822529      0.293464        0.850977   0.823269
# mean symmetry               0.147741      0.071401        0.183027   0.151293
# mean fractal dimension     -0.311631     -0.076437       -0.261477  -0.283110
# radius error                0.679090      0.275869        0.691765   0.732562
# ...

# %%
x=df.drop(['target'],axis=1)
y=df['target']
x.head(2)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33            184.6
# 1                 0.05667  ...         24.99          23.41            158.8
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
#
#    worst concave points  worst symmetry  worst fractal dimension
# ...

# %%
y.head(2)
# Out:
# 0    0.0
# 1    0.0
# Name: target, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)
print("Shape of x_train:",x_train.shape)
print("Shape of x_test:",x_test.shape)
print("Shape of y_train:",y_train.shape)
print("Shape of y_test:",y_test.shape)
# Out:
# Shape of x_train: (455, 30)
# Shape of x_test: (114, 30)
# Shape of y_train: (455,)
# Shape of y_test: (114,)

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pre=model.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
conf_matrix=np.array(confusion_matrix(y_test,y_pre,labels=[1,0]))
conf=pd.DataFrame(conf_matrix,index=['malignant','benign'],columns=['predicted malignant','predicted benign'])
conf
# Out:
#            predicted malignant  predicted benign
# malignant                   66                 0
# benign                       8                40

# %%
sns.heatmap(conf,annot=True)

# %%
print(classification_report(y_test,y_pre))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.83      0.91        48
#          1.0       0.89      1.00      0.94        66
#
#     accuracy                           0.93       114
#    macro avg       0.95      0.92      0.93       114
# weighted avg       0.94      0.93      0.93       114

# %%
#improving our model data normalization

# %%
x_train_min=x_train.min()
x_train_max=x_train.max()
x_train_range=x_train_max-x_train_min
x_train_scaled=(x_train-x_train_min)/x_train_range
x_train_scaled.head(2)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 412     0.114345      0.391003        0.110290    0.05315         0.293907
# 461     0.967343      0.549827        0.988943    1.00000         0.605735
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 412          0.126219        0.087512             0.025487       0.108081
# 461          0.550334        0.851687             0.839463       0.505556
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 412                0.401860  ...      0.072394       0.418354
# 461                0.145814  ...      1.000000       0.509582
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 412         0.080681     0.02846          0.247177           0.156601
# 461         1.000000     1.00000          0.426137           0.386442
#
#      worst concavity  worst concave points  worst symmetry  \
# ...

# %%
#normalizing training set
x_test_min=x_test.min()
x_test_range=(x_test-x_test_min).max()
x_test_scaled=(x_test-x_test_min)/x_test_range
x_test_scaled.head(2)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 269     0.143379      0.576674        0.145236   0.079089         0.391132
# 263     0.422836      0.522138        0.394236   0.307892         0.062431
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 269          0.378409        0.250831             0.149869       0.261526
# 263          0.086702        0.124970             0.148824       0.165342
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 269                0.389277  ...      0.112803       0.462482
# 263                0.088578  ...      0.370190       0.688990
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 269         0.111893    0.056220          0.393047           0.253766
# 263         0.340851    0.249482          0.193382           0.163066
#
#      worst concavity  worst concave points  worst symmetry  \
# ...

# %%
svm_norm=SVC()
svm_norm.fit(x_train_scaled,y_train)
# Out:
# SVC()

# %%
y_pre=svm_norm.predict(x_test_scaled)

# %%
conf_matrix=np.array(confusion_matrix(y_test,y_pre,labels=[1,0]))
conf=pd.DataFrame(conf_matrix,index=['malignant','benign'],columns=['predicted malignant','predicted benign'])
conf
# Out:
#            predicted malignant  predicted benign
# malignant                   61                 5
# benign                       0                48

# %%
sns.heatmap(conf,annot=True)

# %%
print(classification_report(y_test,y_pre))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        48
#          1.0       1.00      0.92      0.96        66
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114
